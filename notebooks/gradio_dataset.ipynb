# %%
import gradio as gr
from ultralytics import YOLO
from PIL import Image
import glob

# Cargar modelo YOLO entrenado
model = YOLO("/home/gnz/GitHub/yolo11_container/runs/detect/train2/weights/best.pt")

# Lista de imágenes del dataset (ejemplo: carpeta de validación)
dataset_images = glob.glob("/home/gnz/GitHub/yolo11_container/valid/images/*.jpg")

# %%
index = 0  # índice actual en el dataset

# Función que retorna la imagen actual y la predicción
def get_image(i=None):
    global index
    
    if i is None:  # Caso inicial
        index = 0
    else:
        index = i % len(dataset_images)

    img_path = dataset_images[index]
    img = Image.open(img_path)

    # Predicción YOLO
    results = model.predict(img, conf=0.25)
    img_with_boxes = results[0].plot()
    pred_img = Image.fromarray(img_with_boxes)

    return img, pred_img, f"Imagen {index+1}/{len(dataset_images)}"

# Funciones para navegación
def next_img():
    return get_image(index + 1)

def prev_img():
    return get_image(index - 1)

# Función para generar galería completa
def generate_gallery():
    preds = []
    for img_path in dataset_images[:50]:  # ⚡ limitamos a 50 para no colgar la app
        img = Image.open(img_path)
        results = model.predict(img, conf=0.25)
        img_with_boxes = results[0].plot()
        preds.append(Image.fromarray(img_with_boxes))
    return preds

# Interfaz con Gradio Blocks
with gr.Blocks() as demo:
    gr.Markdown("## Container OCR Detector - Navegación del Dataset")

    with gr.Tab("🔍 Iterador"):
        with gr.Row():
            input_img = gr.Image(type="pil", label="Imagen de entrada")
            output_img = gr.Image(type="pil", label="Predicción YOLO")

        label = gr.Label(label="Progreso")

        with gr.Row():
            prev_btn = gr.Button("⬅️ Anterior")
            next_btn = gr.Button("Siguiente ➡️")

        demo.load(fn=get_image, inputs=None, outputs=[input_img, output_img, label])
        prev_btn.click(fn=prev_img, inputs=None, outputs=[input_img, output_img, label])
        next_btn.click(fn=next_img, inputs=None, outputs=[input_img, output_img, label])

    with gr.Tab("🖼️ Galería"):
        gr.Markdown("Vista rápida de predicciones YOLO (máx. 50 imágenes).")
        gallery = gr.Gallery(
            label="Predicciones YOLO",
            show_label=False,
            elem_id="gallery",
            columns=[4],
            height="auto"
        )
            
        demo.load(fn=generate_gallery, inputs=None, outputs=gallery)    

demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7867
#
# Could not create share link. Please check your internet connection or our status page: https://status.gradio.app.
# 2025/09/09 11:48:55 [W] [service.go:132] login to server failed: dial tcp 44.237.78.176:7000: i/o timeout
# <div><iframe src="http://127.0.0.1:7867/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Ultralytics 8.3.193 🚀 Python-3.12.3 torch-2.8.0+cu128 CPU (13th Gen Intel Core(TM) i7-13620H)
#
# Model summary (fused): 72 layers, 11,127,132 parameters, 0 gradients, 28.4 GFLOPs
# 0: 384x640 1 cn-11, 1 iso-type, 460.9ms
# Speed: 2.5ms preprocess, 460.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 cn-11, 1 iso-type, 376.8ms
# Speed: 3.8ms preprocess, 376.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cn-11s, 342.5ms
# Speed: 5.1ms preprocess, 342.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cn-11s, 1 iso-type, 327.5ms
# Speed: 5.5ms preprocess, 327.5ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 1 iso-type, 458.6ms
# Speed: 6.8ms preprocess, 458.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11,
1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 1 iso-type, 219.2ms
# Speed: 2.6ms preprocess, 219.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 291.4ms
# Speed: 2.1ms preprocess, 291.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 301.2ms
# Speed: 2.3ms preprocess, 301.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cn-11s, 274.9ms
# Speed: 8.0ms preprocess, 274.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 311.4ms
# Speed: 5.4ms preprocess, 311.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 1 iso-type, 358.9ms
# Speed: 4.5ms preprocess, 358.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 1 iso-type, 399.4ms
# Speed: 2.6ms preprocess, 399.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 255.4ms
# Speed: 3.4ms preprocess, 255.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 1 iso-type, 210.8ms
# Speed: 2.7ms preprocess, 210.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cn-11s, 1 iso-type, 213.5ms
# Speed: 3.8ms preprocess, 213.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 1 iso-type, 205.1ms
# Speed: 3.4ms preprocess, 205.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 214.3ms
# Speed: 2.3ms preprocess, 214.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cn-11s, 1 iso-type, 261.2ms
# Speed: 2.5ms preprocess, 261.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cn-11s, 213.5ms
# Speed: 3.1ms preprocess, 213.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 225.8ms
# Speed: 2.8ms preprocess, 225.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 1 iso-type, 398.3ms
# Speed: 2.1ms preprocess, 398.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 1 iso-type, 355.2ms
# Speed: 4.3ms preprocess, 355.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cn-11s, 1 iso-type, 426.4ms
# Speed: 3.4ms preprocess, 426.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cn-11s, 1 iso-type, 300.2ms
# Speed: 1.9ms preprocess, 300.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 1 iso-type, 381.6ms
# Speed: 3.3ms preprocess, 381.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 1 iso-type, 448.1ms
# Speed: 3.2ms preprocess, 448.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 199.5ms
# Speed: 2.5ms preprocess, 199.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 1 iso-type, 391.6ms
# Speed: 2.2ms preprocess, 391.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 383.2ms
# Speed: 2.1ms preprocess, 383.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cn-11s, 320.6ms
# Speed: 6.2ms preprocess, 320.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cn-11s, 1 iso-type, 330.7ms
# Speed: 6.2ms preprocess, 330.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 1 iso-type, 354.0ms
# Speed: 4.4ms preprocess, 354.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 1 iso-type, 337.0ms
# Speed: 2.8ms preprocess, 337.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cn-11s, 365.4ms
# Speed: 5.2ms preprocess, 365.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 274.4ms
# Speed: 3.1ms preprocess, 274.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cn-11s, 1 iso-type, 410.2ms
# Speed: 5.5ms preprocess, 410.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cn-11s, 1 iso-type, 418.9ms
# Speed: 2.5ms preprocess, 418.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cn-11s, 294.8ms
# Speed: 2.5ms preprocess, 294.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 1 iso-type, 301.6ms
# Speed: 4.3ms preprocess, 301.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 1 iso-type, 290.0ms
# Speed: 5.6ms preprocess, 290.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cn-11s, 274.5ms
# Speed: 2.5ms preprocess, 274.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 1 iso-type, 387.9ms
# Speed: 9.0ms preprocess, 387.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 1 iso-type, 344.2ms
# Speed: 2.6ms preprocess, 344.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 309.7ms
# Speed: 2.6ms preprocess, 309.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 1 iso-type, 350.6ms
# Speed: 6.0ms preprocess, 350.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 1 iso-type, 341.0ms
# Speed: 2.1ms preprocess, 341.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 1 iso-type, 403.2ms
# Speed: 2.7ms preprocess, 403.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 1 iso-type, 324.1ms
# Speed: 2.2ms preprocess, 324.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 1 iso-type, 295.6ms
# Speed: 2.4ms preprocess, 295.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 1 iso-type, 351.2ms
# Speed: 2.8ms preprocess, 351.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cn-11, 1 iso-type, 419.7ms
# Speed: 7.1ms preprocess, 419.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cn-11s, 1 iso-type, 359.3ms
# Speed: 6.1ms preprocess, 359.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cn-11s, 272.7ms
# Speed: 8.2ms preprocess, 272.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cn-11s, 1 iso-type, 352.9ms
# Speed: 2.8ms preprocess, 352.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
