# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.193 🚀 Python-3.12.3 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080 Ti, 12288MiB)
# Setup complete ✅ (16 CPUs, 15.5 GB RAM, 123.0/1006.9 GB disk)

# %%
# 2. Importar librería
from ultralytics import YOLO

# %%
# 3. Cargar modelo base YOLOv11 (puede ser n, s, m, l según tu GPU)
model = YOLO('yolov8n.pt')

# %%
# 4. Entrenar con tu dataset
model.train(
    data="/home/gonzadzz/GitHub/yolo11_container/container-ocr.v11i.yolov11/data.yaml",
    epochs=100,        # número de epochs
    imgsz=640,         # tamaño de la imagen
    batch=16,          # bajar a 8 si se queda sin memoria
    device=0,          # usa tu GPU (0 = primera GPU)
    workers=8,         # hilos para cargar datos
    cache=True         # cachea dataset en RAM/SSD
)
# Out:
# Ultralytics 8.3.193 🚀 Python-3.12.3 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080 Ti, 12288MiB)
# ...
